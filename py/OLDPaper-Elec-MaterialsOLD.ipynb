# %% [markdown]
# ## Different thicknesses of Aluminium and Silicon with fixed electron spectrum beam

# %%
import numpy as np
from matplotlib import pylab as plt
import uproot
from celluloid import Camera
import itertools as it

SMALL_SIZE = 12
MEDIUM_SIZE = 15
BIGGER_SIZE = 19

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

def gausfn(x,a,v):
    return a*np.exp(-(v*x))

# %% [markdown]
# ### Load electron and gamma files
#  ASL  -> Alex Sea Level -> 6.7MeV
#
#  else 5.8 MeV

# %%
filenames_e=[
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-0-um-Air-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-004-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-008-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-012-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-016-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-020-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-040-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-050-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-075-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-100-um-Copper-Edep.root",\
    
    
    
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-001-um-Aluminium-Edep.root",\
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-004-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-008-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-012-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-016-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-020-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-040-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-050-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-075-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-100-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-001-um-PLA-Edep.root",\
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-000-um-PLA-smol-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-100-um-PLA-Edep.root",\
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-001-um-Air-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-300-um-PLA-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-600-um-PLA-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-900-um-PLA-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-1200-um-PLA-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-1500-um-PLA-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-0-um-new-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-4-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-8-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-12-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-16-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-20-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-40-um-Lead-Edep.root"
    
    
    ######
    
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-1-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-4-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-8-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-12-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-16-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-20-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-40-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-50-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-75-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-100-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-200-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-300-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-350-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-400-um-Copper-Edep.root",\
    
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-1-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-4-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-8-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-12-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-16-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-20-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-40-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-50-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-75-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-100-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-200-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-300-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-350-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-400-um-Copper-Edep.root",\
    
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-1-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-4-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-8-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-12-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-16-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-20-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-40-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-50-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-75-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-100-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-200-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-300-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-350-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec_fromPhS1Elec/Total-400-um-Copper-Edep.root",\

#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-1-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-4-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-8-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-12-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-16-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-20-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-40-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-50-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-75-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-100-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-200-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-300-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-350-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_10x10_Elec_PhS1PhS2/Total-400-um-Copper-Edep.root",\
    
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-1-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-4-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-8-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-12-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-16-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-20-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-40-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-50-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-75-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-100-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-200-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-300-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-350-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec/Total-400-um-Silicon-Edep.root",\
    
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-1-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-4-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-8-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-12-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-16-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-20-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-40-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-50-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-75-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-100-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-200-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-300-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-350-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Elec_ASL/Total-400-um-Silicon-Edep.root",\
    
    
    
    
    
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-1-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-4-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-8-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-12-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-16-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-20-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-40-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-50-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-75-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-100-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-200-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-300-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-350-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Gamma/Total-400-um-Copper-Edep.root"
   
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-1-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-4-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-8-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-12-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-16-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-20-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-40-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-50-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-75-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-100-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-200-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-300-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-350-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-400-um-Silicon-Edep.root",\


]

# filenames_e=[
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-0-um-None-Edep.root",\

#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-004-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-008-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-012-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-016-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-020-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-040-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-050-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-075-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Elec/Total-100-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-1-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-4-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-8-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-12-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-16-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-20-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-40-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-50-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-75-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_perp_40x40_Elec/Total-100-um-Copper-Edep.root",\
# ] 


data_frame_dict={}
for files in filenames_e:
    print(f"{files}")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()
#     print("1",data_frame_dict[files])
#     print("2",data_frame_dict[files][0].shape)
#     print("3",data_frame_dict[files][0][0].shape)
# Out:
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-1-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-4-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-8-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-12-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-16-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-20-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-40-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-50-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-75-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-100-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-200-um-Copper-Edep.root
# ...

# %%
filenames_g=[
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-0-um-Air-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-4-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-8-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-12-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-16-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-20-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-40-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-50-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-75-um-Copper-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-100-um-Copper-Edep.root",\
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-1-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-8-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-16-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-12-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-20-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-40-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-50-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-75-um-Aluminium-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-100-um-Aluminium-Edep.root",\
# #     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-1-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-4-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-8-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-12-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-16-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-20-um-Lead-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_40x40_Gamma/Total-40-um-Lead-Edep.root",\
    
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-4-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-8-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-12-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-16-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-20-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-40-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-75-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-100-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-300-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-350-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-400-um-Silicon-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-1-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-4-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-8-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-12-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-16-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-20-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-40-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-50-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-75-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-100-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-200-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-300-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-350-um-Copper-Edep.root",\
    "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-400-um-Copper-Edep.root",\

#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-1-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-4-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-8-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-12-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-16-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-20-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-40-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-50-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-75-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-100-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-200-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-300-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-350-um-Silicon-Edep.root",\
#     "/work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-400-um-Silicon-Edep.root",\
] 


for files in filenames_g:
    print(f"{files}")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()
#     print("1",data_frame_dict[files])
#     print("2",data_frame_dict[files][0].shape)
#     print("3",data_frame_dict[files][0][0].shape)
# Out:
# /work/lb8075/PhaseSpaces/PhS3BigSensor_v2_10x10_Gamma/Total-1-um-Copper-Edep.root
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e9e206c61102> in <module>
#      72 for files in filenames_g:
#      73     print(f"{files}")
# ---> 74     data_frame_dict[files]=uproot.open(files)["histo"].numpy()
#      75 #     print("1",data_frame_dict[files])
#      76 #     print("2",data_frame_dict[files][0].shape)
#
# ~/.conda/envs/KDEpy/lib/python3.8/site-packages/uproot/rootio.py in open(path, localsource, xrootdsource, httpsource, **options)
#      52         else:
#      53             openfcn = localsource
# ---> 54         return ROOTDirectory.read(openfcn(path), **options)
#      55
#      56     elif _bytesid(parsed.scheme) == b"root":
#
# ~/.conda/envs/KDEpy/lib/python3.8/site-packages/uproot/rootio.py in <lambda>(path)
# ...

# %%
for files in filenames_e:
    print(files)
    crop_filename=files.split("/")[6]
    print(crop_filename)
    thick=crop_filename.split("-")[1]
    material=crop_filename.split("-")[3]
    print(thick,material)

for files in filenames_g:
        
    crop_filename_g=files.split("/")[6]
    print(crop_filename_g)
    thick_g=crop_filename_g.split("-")[1]
    material_g=crop_filename_g.split("-")[3]
    print(thick_g,material_g)
# Out:
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-1-um-Copper-Edep.root
# Total-1-um-Copper-Edep.root
# 1 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-4-um-Copper-Edep.root
# Total-4-um-Copper-Edep.root
# 4 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-8-um-Copper-Edep.root
# Total-8-um-Copper-Edep.root
# 8 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-12-um-Copper-Edep.root
# Total-12-um-Copper-Edep.root
# 12 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-16-um-Copper-Edep.root
# Total-16-um-Copper-Edep.root
# 16 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-20-um-Copper-Edep.root
# Total-20-um-Copper-Edep.root
# 20 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-40-um-Copper-Edep.root
# Total-40-um-Copper-Edep.root
# 40 Copper
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-50-um-Copper-Edep.root
# ...

# %% [markdown]
# ### Fold Phase Space into quadrant

# %%
for files in filenames_e:
    plt.subplots(1,1,figsize=(12,5))

    crop_filename=files.split("/")[6]
    print(crop_filename)
    label1=int(crop_filename.split("-")[1])

    print(files)
    
    dic=data_frame_dict[files][0]

    d1,d2=np.split(dic,2)
    d2=np.flipud(d2)
    d3=d1+d2
    d4,d5=np.split(d3,2,axis=1)
    d4=np.fliplr(d4)
    d6=d4+d5
    plt.imshow(d6,vmax=2000)
#     print(data_frame_dict[files][0])
#     print(d6)
    data_frame_dict[files]=d6

# plt.yscale('log')
# plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
    plt.colorbar()
    plt.show()
    

# for files in filenames_g:
#     plt.subplots(1,1,figsize=(12,5))

#     crop_filename_g=files.split("/")[5]
#     print(crop_filename_g)
#     label1_g=int(crop_filename_g.split("-")[1])

#     print(label1_g)
    
#     dic=data_frame_dict[files][0]

#     d1,d2=np.split(dic,2)
#     d2=np.flipud(d2)
#     d3=d1+d2
#     d4,d5=np.split(d3,2,axis=1)
#     d4=np.fliplr(d4)
#     d6=d4+d5
#     plt.imshow(d6,vmax=800)
#     print(d6.shape)
#     data_frame_dict[files]=d6

# # plt.yscale('log')
# # plt.legend()
# # plt.xlim(0,5.8)
# # plt.ylim(0.001,1)
#     plt.colorbar()
#     plt.show()
# Out:
# Total-1-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-1-um-Copper-Edep.root
# Total-4-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-4-um-Copper-Edep.root
# Total-8-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-8-um-Copper-Edep.root
# Total-12-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-12-um-Copper-Edep.root
# Total-16-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-16-um-Copper-Edep.root
# Total-20-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-20-um-Copper-Edep.root
# Total-40-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-40-um-Copper-Edep.root
# Total-50-um-Copper-Edep.root
# /work/lb8075/PhaseSpaces/PS3/PhS3BigSensor_v2_10x10_Elec/Total-50-um-Copper-Edep.root
# Total-75-um-Copper-Edep.root
# ...

# %% [markdown]
# ### Check field shape

# %%
for files in filenames_e:
    plt.subplots(1,1,figsize=(12,5))

    crop_filename=files.split("/")[5]
    print(crop_filename)
    label1=int(crop_filename.split("-")[1])

    print(label1)
    
    dic=data_frame_dict[files]

#     plt.imshow(dic)
    plt.plot(dic[100:110,:].mean(axis=0))

# plt.yscale('log')
# plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
#     plt.colorbar()
    plt.show()
    

for files in filenames_g:
    plt.subplots(1,1,figsize=(12,5))

    crop_filename_g=files.split("/")[5]
    print(crop_filename_g)
    label1_g=int(crop_filename_g.split("-")[1])

    print(label1_g)
    
    dic=data_frame_dict[files]

    plt.imshow(dic)

# plt.yscale('log')
# plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
    plt.colorbar()
    plt.show()
# Out:
# Total-1-um-Copper-Edep.root
# 1
# Total-4-um-Copper-Edep.root
# 4
# Total-8-um-Copper-Edep.root
# 8
# Total-12-um-Copper-Edep.root
# 12
# Total-16-um-Copper-Edep.root
# 16
# Total-20-um-Copper-Edep.root
# 20
# Total-40-um-Copper-Edep.root
# 40
# Total-50-um-Copper-Edep.root
# 50
# Total-75-um-Copper-Edep.root
# 75
# Total-100-um-Copper-Edep.root
# 100
# Total-200-um-Copper-Edep.root
# 200
# Total-300-um-Copper-Edep.root
# 300
# Total-350-um-Copper-Edep.root
# 350
# Total-400-um-Copper-Edep.root
# 400
# Total-1-um-Copper-Edep.root
# 1
# Total-4-um-Copper-Edep.root
# 4
# Total-8-um-Copper-Edep.root
# 8
# Total-12-um-Copper-Edep.root
# 12
# Total-16-um-Copper-Edep.root
# 16
# Total-20-um-Copper-Edep.root
# 20
# Total-40-um-Copper-Edep.root
# 40
# Total-50-um-Copper-Edep.root
# 50
# Total-75-um-Copper-Edep.root
# 75
# Total-100-um-Copper-Edep.root
# 100
# Total-200-um-Copper-Edep.root
# 200
# Total-300-um-Copper-Edep.root
# 300
# Total-350-um-Copper-Edep.root
# 350
# ...

# %% [markdown]
# ### Set ranges for areas to study

# %%
#centre
range1sx=0
range1ex=5
range1sy=120
range1ey=125

# y edge
range2sx=0
range2ex=5
range2sy=5 #35
range2ey=10 #40

# x edge
range3sx=115 #90
range3ex=120 #95
range3sy=120
range3ey=125

#corner
range4sx=90
range4ex=95
range4sy=35
range4ey=40

# %% [markdown]
# ### Plot electron field for different materials for both beam energies

# %%
histo_dict_e={}
Energy=""
scale_factor=0.02

for mat in ["Silicon","Copper"]:
    histo_dict_e[f"e_min_6p7_{mat}_centre"]=np.array([])
    histo_dict_e[f"e_min_6p7_{mat}_y"]=np.array([])
    histo_dict_e[f"e_min_6p7_{mat}_x"]=np.array([])
    histo_dict_e[f"e_min_6p7_{mat}_corner"]=np.array([])
    histo_dict_e[f"thick_6p7_{mat}"]=np.array([])
    histo_dict_e[f"e_min_5p8_{mat}_centre"]=np.array([])
    histo_dict_e[f"e_min_5p8_{mat}_y"]=np.array([])
    histo_dict_e[f"e_min_5p8_{mat}_x"]=np.array([])
    histo_dict_e[f"e_min_5p8_{mat}_corner"]=np.array([])
    histo_dict_e[f"thick_5p8_{mat}"]=np.array([])


for files in filenames_e:

    crop_filename=files.split("/")[5]
    thickness=int(crop_filename.split("-")[1])
    dic=data_frame_dict[files]
    dic2=data_frame_dict[files]
    if ("Elec" not in files ):
        continue

    if ("ASL" in files):
        Energy="6p7"
    elif("_fromPhS1Elec" in  files):
        continue
    else:
        Energy="5p8"
        
        
    material=crop_filename.split("-")[3]
    histo_dict_e[f"e_min_{Energy}_{material}_centre"]=np.append(histo_dict_e[f"e_min_{Energy}_{material}_centre"],dic[range1sy:range1ey,range1sx:range1ex].mean())
    histo_dict_e[f"e_min_{Energy}_{material}_y"]=np.append(histo_dict_e[f"e_min_{Energy}_{material}_y"],dic[range2sy:range2ey,range2sx:range2ex].mean())
    histo_dict_e[f"e_min_{Energy}_{material}_x"]=np.append(histo_dict_e[f"e_min_{Energy}_{material}_x"],dic[range3sy:range3ey,range3sx:range3ex].mean())
    histo_dict_e[f"e_min_{Energy}_{material}_corner"]=np.append(histo_dict_e[f"e_min_{Energy}_{material}_corner"],dic[range4sy:range4ey,range4sx:range4ex].mean())
    histo_dict_e[f"thick_{Energy}_{material}"]=np.append(histo_dict_e[f"thick_{Energy}_{material}"],thickness)

plt.figure(figsize=(13,8))
for mat in ["Silicon","Copper"]:
    material=mat
#     plt.plot(histo_dict[f"thick_6p7_{material}"],histo_dict[f"e_min_6p7_{material}_centre"],label=f"{mat} centre 6.7 MeV",marker='o',linestyle='none')
    plt.plot(histo_dict_e[f"thick_5p8_{material}"],histo_dict_e[f"e_min_5p8_{material}_centre"]*scale_factor,label=f"{mat} centre 5.8 MeV",marker='o',linestyle='none')
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('Edep epi layer')
plt.xlim(-11,100)
plt.ylim(15,100)
plt.grid(True)

plt.show()

# %%
histo_dict={}
Energy=""

for mat in ["Silicon","Copper"]:
    histo_dict[f"e_min_6p7_{mat}_centre"]=np.array([])
    histo_dict[f"e_min_6p7_{mat}_y"]=np.array([])
    histo_dict[f"e_min_6p7_{mat}_x"]=np.array([])
    histo_dict[f"e_min_6p7_{mat}_corner"]=np.array([])
    histo_dict[f"thick_6p7_{mat}"]=np.array([])
    histo_dict[f"e_min_5p8_{mat}_centre"]=np.array([])
    histo_dict[f"e_min_5p8_{mat}_y"]=np.array([])
    histo_dict[f"e_min_5p8_{mat}_x"]=np.array([])
    histo_dict[f"e_min_5p8_{mat}_corner"]=np.array([])
    histo_dict[f"thick_5p8_{mat}"]=np.array([])


for files in filenames_e:

    crop_filename=files.split("/")[5]
    thickness=int(crop_filename.split("-")[1])
    dic=data_frame_dict[files]
    if ("Gamma" not in files ):
        continue

    if ("ASL" in files):
        Energy="6p7"
    else:
        Energy="5p8"
        
        
    material=crop_filename.split("-")[3]
    histo_dict[f"e_min_{Energy}_{material}_centre"]=np.append(histo_dict[f"e_min_{Energy}_{material}_centre"],dic[range1sy:range1ey,range1sx:range1ex].mean())
    histo_dict[f"e_min_{Energy}_{material}_y"]=np.append(histo_dict[f"e_min_{Energy}_{material}_y"],dic[range2sy:range2ey,range2sx:range2ex].mean())
    histo_dict[f"e_min_{Energy}_{material}_x"]=np.append(histo_dict[f"e_min_{Energy}_{material}_x"],dic[range3sy:range3ey,range3sx:range3ex].mean())
    histo_dict[f"e_min_{Energy}_{material}_corner"]=np.append(histo_dict[f"e_min_{Energy}_{material}_corner"],dic[range4sy:range4ey,range4sx:range4ex].mean())
    histo_dict[f"thick_{Energy}_{material}"]=np.append(histo_dict[f"thick_{Energy}_{material}"],thickness)

plt.figure(figsize=(13,8))
for mat in ["Silicon","Copper"]:
    material=mat
#     plt.plot(histo_dict[f"thick_6p7_{material}"],histo_dict[f"e_min_6p7_{material}_centre"],label=f"{mat} centre 6.7 MeV",marker='o',linestyle='none')
    plt.plot(histo_dict[f"thick_5p8_{material}"],histo_dict[f"e_min_5p8_{material}_centre"],label=f"{mat} centre 5.8 MeV",marker='o',linestyle='none')
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('Edep epi layer')
plt.xlim(-11,100)
plt.ylim(15,100)
plt.grid(True)

plt.show()

# %%
plt.subplots(1,1,figsize=(11,7))
electrons=histo_dict_e["e_min_5p8_Copper_centre"]/50
gammas=histo_dict["e_min_5p8_Copper_centre"]
thickness=histo_dict["thick_5p8_Copper"]
scaleF=gammas[0]
plt.plot(thickness,(electrons+gammas)/scaleF,label="Addition",marker='o',linestyle='none')
plt.plot(thickness,electrons/scaleF,label="Electrons",marker='o',linestyle='none')
plt.plot(thickness,gammas/scaleF,label="Gammas",marker='o',linestyle='none')


plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('Energy Deposit (MeV)')
plt.savefig('Copper_AllElec.png')

# %%
plt.subplots(1,1,figsize=(11,7))
electrons=histo_dict_e["e_min_5p8_Copper_centre"]/50
gammas=histo_dict["e_min_5p8_Copper_centre"]
thickness=histo_dict["thick_5p8_Copper"]
scaleF=gammas[0]
plt.plot(thickness,(electrons+gammas)/scaleF,label="Addition",marker='o',linestyle='none')
plt.plot(thickness,electrons/scaleF,label="Electrons",marker='o',linestyle='none')
plt.plot(thickness,gammas/scaleF,label="Gammas",marker='o',linestyle='none')


plt.legend(loc='upper left')
plt.xlim(-5,105)
plt.ylim(0,8)
plt.xlabel('Thickness (um)')
plt.ylabel('Energy Deposit (MeV)')
plt.savefig('Copper_AllElec_Zoom.png')

# %% [markdown]
# ## HERE BE DRAGONS

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_si_10,((e_min_g_si_10/e_min_g_si_10[0])-1),label="Silicon",marker='o',linestyle='none')

plt.plot(thick_g_cu,((e_min_g_cu/e_min_g_cu[0])-1),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('gamma+e')
# Out:
# Text(0, 0.5, 'gamma+e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_si_10,((e_min_si/e_min_si[0])-1),label="Silicon",marker='o',linestyle='none')

plt.plot(thick_g_cu,((e_min_cu/e_min_cu[0])-1),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('gamma+e')
# Out:
# Text(0, 0.5, 'gamma+e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_si_10,((e_min_g_si_10/e_min_g_si_10[0])-1)+((e_min_si/e_min_si[0])-1),label="Silicon",marker='o',linestyle='none')

plt.plot(thick_g_cu,((e_min_g_cu/e_min_g_cu[0])-1)+((e_min_cu/e_min_cu[0])-1),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('gamma+e')
# Out:
# Text(0, 0.5, 'gamma+e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_si_10[1:],-((e_min_si[1:]/e_min_si[0])-1)/(((e_min_g_si_10[1:]/e_min_g_si_10[0])-1)+((e_min_si[1:]/e_min_si[0])-1)),label="Silicon",marker='o',linestyle='none')

plt.plot(thick_g_cu[1:],-((e_min_cu[1:]/e_min_cu[0])-1)/(((e_min_g_cu[1:]/e_min_g_cu[0])-1)+((e_min_cu[1:]/e_min_cu[0])-1)),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('gamma+e')
# Out:
# Text(0, 0.5, 'gamma+e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_si_10[1:],-((e_min_si[1:]/e_min_si[0])-1)/(((e_min_g_si_10[1:]/e_min_g_si_10[0])-1)+((e_min_si[1:]/e_min_si[0])-1)),label="Silicon",marker='o',linestyle='none')

plt.plot(thick_g_cu[1:],-((e_min_cu[1:]/e_min_cu[0])-1)/(((e_min_g_cu[1:]/e_min_g_cu[0])-1)+((e_min_cu[1:]/e_min_cu[0])-1)),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('gamma+e')
# Out:
# Text(0, 0.5, 'gamma+e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_cu[1:],(e_min_g_cu[1:]/e_min_g_cu[0])/(1-(e_min_cu[1:]/e_min_cu[0])),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])/(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])/(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])/(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
# plt.plot(thick_g_al,(e_min_g_al/e_min_g_al[0])/(e_min_al/e_min_al[0]),label="Aluminium",marker='o',linestyle='none')
plt.plot(thick_g_si_10[1:],(e_min_g_si_10[1:]/e_min_g_si_10[0])/(1-(e_min_si[1:]/e_min_si[0])),label="Silicon",marker='o',linestyle='none')
# plt.plot(thick_g_pb,(e_min_g_pb/e_min_g_pb[0])/(e_min_pb/e_min_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
plt.ylim(-100,40)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('Ratio gamma/e')
# Out:
# Text(0, 0.5, 'Ratio gamma/e')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(thick_g_cu,(e_min_cu/e_min_cu[0])/(e_min_g_cu/e_min_g_cu[0]),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_cu2/e_min_cu2[0])/(e_min_g_cu2/e_min_g_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_cu3/e_min_cu3[0])/(e_min_g_cu3/e_min_g_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_cu4/e_min_cu4[0])/(e_min_g_cu4/e_min_g_cu4[0]),label="Copper top right",marker='o',linestyle='none')
plt.plot(thick_g_al,(e_min_al/e_min_al[0])/(e_min_g_al/e_min_g_al[0]),label="Aluminium",marker='o',linestyle='none')
plt.plot(thick_g_pb,(e_min_pb/e_min_pb[0])/(e_min_g_pb/e_min_g_pb[0]),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,1)
plt.legend()
plt.xlabel('Thickness (um)')
plt.ylabel('Ratio e/gamma')
# Out:
# Text(0, 0.5, 'Ratio e/gamma')

# %%
plt.subplots(1,1,figsize=(11,7))

plt.plot(e_min_g_cu/e_min_g_cu[0],(e_min_g_cu/e_min_g_cu[0])/((e_min_g_cu/e_min_g_cu[0])+(e_min_cu/e_min_cu[0])),label="Copper centre",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu2/e_min_g_cu2[0])+(e_min_cu2/e_min_cu2[0]),label="Copper top",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu3/e_min_g_cu3[0])+(e_min_cu3/e_min_cu3[0]),label="Copper right",marker='o',linestyle='none')
# plt.plot(thick_g_cu,(e_min_g_cu4/e_min_g_cu4[0])+(e_min_cu4/e_min_cu4[0]),label="Copper top right",marker='o',linestyle='none')
plt.plot(e_min_g_al/e_min_g_al[0],(e_min_g_al/e_min_g_al[0])/((e_min_g_al/e_min_g_al[0])+(e_min_al/e_min_al[0])),label="Aluminium",marker='o',linestyle='none')
plt.plot(e_min_g_pb/e_min_g_pb[0],(e_min_g_pb/e_min_g_pb[0])/((e_min_g_pb/e_min_g_pb[0])+(e_min_pb/e_min_pb[0])),label="Lead",marker='o',linestyle='none')
# plt.xlim(0,20)
# plt.ylim(0,5)
plt.legend()
plt.xlabel('gamma')
plt.ylabel('gamma/gamma+e')
# Out:
# Text(0, 0.5, 'gamma/gamma+e')

# %%
# plt.plot(thick_al,e_min_al,"r.",label="Al")
# plt.plot(thick,e_min,"b.",label="Si")
plt.plot(thick_cu,e_min_cu,"g.",label="Cu")
plt.legend()
plt.show()
print(thick_al,e_min_al)
# Out:
# [  8.  16.  12.  20.  40.  50.  75. 100.] [15.96378136 18.23276901 17.00736046 19.48436546 24.81881905 27.36265945
#  32.76774979 37.55938339]

# %%
for files in filenames_e:
    plt.subplots(1,1,figsize=(12,12))

    dic=data_frame_dict[files][0]
    _=plt.imshow(dic)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-c815d93b38fd> in <module>
#       3
#       4     dic=data_frame_dict[files][0]
# ----> 5     _=plt.imshow(dic)
#       6     plt.show()
#
# ~/.conda/envs/KDEpy/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/.conda/envs/KDEpy/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
filenames_e=[
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-010_030_060_080_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-010_030_060_080_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-004_008_012_016_peakum-down-Copper-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-010_030_060_080_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-010_030_060_080_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-140_160_250_300_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-140_160_250_300_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-350_400_450_700_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Elec_Materials/Total-350_400_450_700_peakum-down-Silicon-Edep.root"
] 


data_frame_dict={}
for files in filenames_e:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()

# %%
plt.subplots(1,1,figsize=(18,7))
# e_min=np.array([])
# thick=np.array([])
# e_min_al=np.array([])
# thick_al=np.array([])
# e_min_cu=np.array([])
# thick_cu=np.array([])
# zero=data_frame_dict[filenames_e[0]][0][:,300:700].mean(axis=1)[250:260].mean()

# # zero=data_frame_dict[filenames_e[0]][0][:,270:370].mean(axis=1)[50:150].mean()
# e_min=np.append(e_min,zero)
# thick=np.append(thick,0)
# e_min_al=np.append(e_min_al,zero)
# thick_al=np.append(thick_al,0)
# e_min_cu=np.append(e_min_cu,zero)
# thick_cu=np.append(thick_cu,0)

for files in filenames_e:
    if "Silicon" in files:
        lstyle="-"
    else:
        lstyle="-"
    dic=data_frame_dict[files][0][380:420,:].mean(axis=0)
    dic2=data_frame_dict[files][0][580:620,:].mean(axis=0)
#     dic=dic.reshape(int(len(dic)/6),6).mean(axis=1)
    histe=plt.plot(dic,label=files[51:66],linestyle=lstyle)
    histe=plt.plot(dic2,label=files[51:66],linestyle=lstyle)
    
    if "Silicon" in files:
    
    #skipping because I messed up the sim on this
    
        e_min=np.append(e_min,dic[380:420].mean())
        thick=np.append(thick,int(files[59:62]))

        e_min=np.append(e_min,dic[580:620].mean())
        thick=np.append(thick,int(files[63:66]))

        e_min=np.append(e_min,dic2[380:420].mean())
        thick=np.append(thick,int(files[51:54]))

        e_min=np.append(e_min,dic2[580:620].mean())
        thick=np.append(thick,int(files[55:58]))
    elif "Copper" in files:
        
        e_min_cu=np.append(e_min_cu,dic[380:420].mean())
        thick_cu=np.append(thick_cu,int(files[59:62]))

        e_min_cu=np.append(e_min_cu,dic[580:620].mean())
        thick_cu=np.append(thick_cu,int(files[63:66]))
        
        e_min_cu=np.append(e_min_cu,dic2[380:420].mean())
        thick_cu=np.append(thick_cu,int(files[51:54]))

        e_min_cu=np.append(e_min_cu,dic2[580:620].mean())
        thick_cu=np.append(thick_cu,int(files[55:58]))
        
    else:
        
    #skipping because I messed up the sim on this
        
    
        e_min_al=np.append(e_min_al,dic[380:420].mean())
        thick_al=np.append(thick_al,int(files[59:62]))

        e_min_al=np.append(e_min_al,dic[580:620].mean())
        thick_al=np.append(thick_al,int(files[63:66]))

        e_min_al=np.append(e_min_al,dic2[380:420].mean())
        thick_al=np.append(thick_al,int(files[51:54]))

        e_min_al=np.append(e_min_al,dic2[580:620].mean())
        thick_al=np.append(thick_al,int(files[55:58]))
#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
filenames_g=[
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-020_040_060_080_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-100_120_140_160_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-180_200_250_300_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-020_040_060_080_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-100_120_140_160_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-180_200_250_300_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-010_020_030_040_peakum-down-Copper-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-050_060_070_080_peakum-down-Copper-Edep.root",\
#             "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials_x200xsec/Total-010_030_250_300_peakum-down-Silicon-329files-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-010_030_250_300_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-350_400_450_700_peakum-down-Aluminium-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-010_030_250_300_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-350_400_450_700_peakum-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-004_008_012_016_peakum-down-Copper-Edep.root"
] 


data_frame_dict={}
for files in filenames_g:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()
# Out:
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-020_040_060_080_peakum-down-Aluminium-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-100_120_140_160_peakum-down-Aluminium-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-180_200_250_300_peakum-down-Aluminium-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-020_040_060_080_peakum-down-Silicon-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-100_120_140_160_peakum-down-Silicon-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-180_200_250_300_peakum-down-Silicon-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-010_020_030_040_peakum-down-Copper-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-050_060_070_080_peakum-down-Copper-Edep.root
#
# /work/lb8075/PhaseSpaces/PhS3_Gamma_Materials/Total-010_030_250_300_peakum-down-Aluminium-Edep.root
#
# ...

# %%
plt.subplots(1,1,figsize=(18,7))
e_min_gamma=np.array([])
thick_gamma=np.array([])
e_min_gamma_al=np.array([])
thick_gamma_al=np.array([])
e_min_gamma_cu=np.array([])
thick_gamma_cu=np.array([])
zero=data_frame_dict[filenames_g[0]][0][:,300:700].mean(axis=1)[250:260].mean()

# zero=data_frame_dict[filenames_e[0]][0][:,270:370].mean(axis=1)[50:150].mean()
e_min_gamma=np.append(e_min_gamma,zero)
thick_gamma=np.append(thick_gamma,0)
e_min_gamma_al=np.append(e_min_gamma_al,zero)
thick_gamma_al=np.append(thick_gamma_al,0)
e_min_gamma_cu=np.append(e_min_gamma_cu,zero)
thick_gamma_cu=np.append(thick_gamma_cu,0)

for files in filenames_g:
    if "Silicon" in files:
        lstyle="-"
    else:
        lstyle="-"
    dic=data_frame_dict[files][0][380:420,:].mean(axis=0)
    dic2=data_frame_dict[files][0][580:620,:].mean(axis=0)
#     dic=dic.reshape(int(len(dic)/6),6).mean(axis=1)
#     histe=plt.plot(dic,label=files[51+1:66+1],linestyle=lstyle)
#     histe=plt.plot(dic2,label=files[51+1:66+1],linestyle=lstyle)
    
    if "329" in files:
        histe=plt.plot(dic/0.329,label=files[51+10:66+11],linestyle=lstyle)
#         histe=plt.plot(dic2/0.329,label=files[51+10:66+14],linestyle=lstyle)
    else:
        histe=plt.plot(dic,label=files[51+1:66+1],linestyle=lstyle)
#         histe=plt.plot(dic2,label=files[51+1:66+1],linestyle=lstyle)
    
    
    if "Silicon" in files:
    
        
#         if "329" in files:
#             e_min_gamma=np.append(e_min_gamma,dic[380:420].mean()/0.329)
#             e_min_gamma=np.append(e_min_gamma,dic[580:620].mean()/0.329)
#             e_min_gamma=np.append(e_min_gamma,dic2[380:420].mean()/0.329)
#             e_min_gamma=np.append(e_min_gamma,dic2[580:620].mean()/0.329)
#             thick_gamma=np.append(thick_gamma,int(files[59+10:62+10]))
#             thick_gamma=np.append(thick_gamma,int(files[63+10:66+10]))
#             thick_gamma=np.append(thick_gamma,int(files[51+10:54+10]))
#             thick_gamma=np.append(thick_gamma,int(files[55+10:58+10]))
#         else:
        if "010_030_250_300" not in files:
            e_min_gamma=np.append(e_min_gamma,dic[380:420].mean())
            e_min_gamma=np.append(e_min_gamma,dic[580:620].mean())
            thick_gamma=np.append(thick_gamma,int(files[59+1:62+1]))
            thick_gamma=np.append(thick_gamma,int(files[63+1:66+1]))
        
        

        e_min_gamma=np.append(e_min_gamma,dic2[380:420].mean())
        e_min_gamma=np.append(e_min_gamma,dic2[580:620].mean())

        thick_gamma=np.append(thick_gamma,int(files[51+1:54+1]))
        thick_gamma=np.append(thick_gamma,int(files[55+1:58+1]))

    elif "Copper" in files:
        
        e_min_gamma_cu=np.append(e_min_gamma_cu,dic[380:420].mean())
        thick_gamma_cu=np.append(thick_gamma_cu,int(files[59+1:62+1]))

        e_min_gamma_cu=np.append(e_min_gamma_cu,dic[580:620].mean())
        thick_gamma_cu=np.append(thick_gamma_cu,int(files[63+1:66+1]))
        
        e_min_gamma_cu=np.append(e_min_gamma_cu,dic2[380:420].mean())
        thick_gamma_cu=np.append(thick_gamma_cu,int(files[51+1:54+1]))

        e_min_gamma_cu=np.append(e_min_gamma_cu,dic2[580:620].mean())
        thick_gamma_cu=np.append(thick_gamma_cu,int(files[55+1:58+1]))
        
    else:
        if "010_030_250_300" not in files:
                
    
            e_min_gamma_al=np.append(e_min_gamma_al,dic[380:420].mean())
            thick_gamma_al=np.append(thick_gamma_al,int(files[59+1:62+1]))

            e_min_gamma_al=np.append(e_min_gamma_al,dic[580:620].mean())
            thick_gamma_al=np.append(thick_gamma_al,int(files[63+1:66+1]))

        e_min_gamma_al=np.append(e_min_gamma_al,dic2[380:420].mean())
        thick_gamma_al=np.append(thick_gamma_al,int(files[51+1:54+1]))

        e_min_gamma_al=np.append(e_min_gamma_al,dic2[580:620].mean())
        thick_gamma_al=np.append(thick_gamma_al,int(files[55+1:58+1]))
#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.xlim(0,100)
# plt.ylim(0,5)


# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
arr1inds = thick_gamma_cu.argsort()
thick_gamma_cu = thick_gamma_cu[arr1inds]
e_min_gamma_cu = e_min_gamma_cu[arr1inds]

arr1inds = thick_cu.argsort()
thick_cu = thick_cu[arr1inds]
e_min_cu = e_min_cu[arr1inds]

arr1inds = thick_gamma.argsort()
thick_gamma = thick_gamma[arr1inds]
e_min_gamma = e_min_gamma[arr1inds]

arr1inds = thick.argsort()
thick = thick[arr1inds]
e_min = e_min[arr1inds]

arr1inds = thick_gamma_al.argsort()
thick_gamma_al = thick_gamma_al[arr1inds]
e_min_gamma_al = e_min_gamma_al[arr1inds]

arr1inds = thick_al.argsort()
thick_al = thick_al[arr1inds]
e_min_al = e_min_al[arr1inds]

# %%
plt.plot(thick_gamma_al,e_min_gamma_al,"r.",label="Al")
plt.plot(thick_gamma,e_min_gamma,"b.",label="Si")
plt.plot(thick_gamma_cu,e_min_gamma_cu,"g.",label="Cu")
plt.legend()
plt.show()

# %%
fig,ax=plt.subplots(1,1,figsize=(5,4))
ax.plot(thick_gamma,e_min_gamma,"b+",label="Si")

ax.plot(thick_gamma_al,e_min_gamma_al,"r.",label="Al")
ax.plot(thick_gamma_cu,e_min_gamma_cu,"g^",label="Cu")
ax.set_xlabel("Thickness ($\mu$m)")
ax.set_ylabel("Energy Deposit (MeV)")
ax.set_xlim(-8,415)
ax.set_ylim(6,56)
ax.legend(loc="lower right")
# ax[0].show()
fig2,ax2=plt.subplots(1,1,figsize=(5,4))
ax2.plot(thick,e_min*0.5,"b+",label="Si")

ax2.plot(thick_al,e_min_al*0.5,"r.",label="Al")
ax2.plot(thick_cu,e_min_cu*0.5,"g^",label="Cu")
ax2.set_xlabel("Thickness ($\mu$m)")
ax2.set_ylabel("Energy Deposit (MeV)")
ax2.set_xlim(-8,415)
ax2.set_ylim(3.0,5.7)


ax2.legend()

# ax[1,0].plot(thick_al,e_min_gamma_al+e_min_al*0.5,"r.",label="Al")
# ax[1,0].plot(thick,e_min_gamma+e_min*0.5,"b.",label="Si")
# ax[1,0].plot(thick_cu,e_min_gamma_cu+e_min_cu*0.5,"g.",label="Cu")
# ax[1,0].legend()
# ax[0,0].set_xlim(0,20)

# ax[0,1].set_xlim(0,20)
plt.show()
fig.savefig("Material_thickness_gamma.png")
fig2.savefig("Material_thickness_elec.png")

# %%
all_ans_gamma=np.array([])
anew=e_min_gamma_cu[::-1]
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)
    all_ans_gamma=np.append(all_ans_gamma,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma))
print('next"')
all_ans=np.array([])
anew=e_min_cu[::-1]*0.5
print(anew)
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)

    all_ans=np.append(all_ans,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma),np.argmin(all_ans),np.min(all_ans))
all_ans_tot=all_ans_gamma/all_ans
print(all_ans_tot)
print(np.argmax(all_ans_tot),np.max(all_ans_tot))
# Out:
# 0 44.27892303466797 41.73707580566406 2.5418472290039062
# 1 44.27892303466797 39.02463912963867 5.254283905029297
# 2 44.27892303466797 36.0723762512207 8.206546783447266
# 3 44.27892303466797 33.48252487182617 10.796398162841797
# 4 44.27892303466797 29.705718994140625 14.573204040527344
# 5 44.27892303466797 25.170822143554688 19.10810089111328
# 6 44.27892303466797 23.105642318725586 21.173280715942383
# 7 44.27892303466797 20.801719665527344 23.477203369140625
# 8 44.27892303466797 19.512426376342773 24.766496658325195
# 9 44.27892303466797 18.06557273864746 26.213350296020508
# 10 44.27892303466797 14.750079154968262 29.528843879699707
# 11 44.27892303466797 9.417659759521484 34.861263275146484
# 12 41.73707580566406 39.02463912963867 2.7124366760253906
# 13 41.73707580566406 36.0723762512207 5.664699554443359
# 14 41.73707580566406 33.48252487182617 8.25455093383789
# 15 41.73707580566406 29.705718994140625 12.031356811523438
# ...

# %%
all_ans_gamma=np.array([])
anew=e_min_gamma[::-1]
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)
    all_ans_gamma=np.append(all_ans_gamma,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma))
print('next"')
all_ans=np.array([])
anew=e_min[::-1]*0.5
print(anew)
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)

    all_ans=np.append(all_ans,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma),np.argmin(all_ans),np.min(all_ans))
all_ans_tot=all_ans_gamma/all_ans
print(all_ans_tot)
print(np.argmax(all_ans_tot),np.max(all_ans_tot))
# Out:
# 0 64.25731658935547 52.39196014404297 11.8653564453125
# 1 64.25731658935547 49.56501007080078 14.692306518554688
# 2 64.25731658935547 46.4576301574707 17.799686431884766
# 3 64.25731658935547 41.66472625732422 22.59259033203125
# 4 64.25731658935547 38.15972900390625 26.09758758544922
# 5 64.25731658935547 34.24820327758789 30.009113311767578
# 6 64.25731658935547 32.57210922241211 31.68520736694336
# 7 64.25731658935547 31.575510025024414 32.681806564331055
# 8 64.25731658935547 29.6319580078125 34.62535858154297
# 9 64.25731658935547 27.59726333618164 36.66005325317383
# 10 64.25731658935547 25.43024253845215 38.82707405090332
# 11 64.25731658935547 23.332483291625977 40.92483329772949
# 12 64.25731658935547 20.76028060913086 43.49703598022461
# 13 64.25731658935547 17.773202896118164 46.484113693237305
# 14 64.25731658935547 16.17573356628418 48.08158302307129
# 15 64.25731658935547 14.307385444641113 49.949931144714355
# ...

# %%
all_ans_gamma=np.array([])
anew=e_min_gamma_al[::-1]
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)
    all_ans_gamma=np.append(all_ans_gamma,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma))
print('next"')
all_ans=np.array([])
anew=e_min_al[::-1]*0.5
print(anew)
combs=it.combinations(anew,2)
for j,comb in enumerate(combs):
    ans=abs(comb[0]-comb[1])
#     print(ans)
    print(j,comb[0],comb[1],ans)

    all_ans=np.append(all_ans,ans)
    
# print(np.argmax(all_ans_gamma),np.max(all_ans_gamma),np.argmin(all_ans),np.min(all_ans))
all_ans_tot=all_ans_gamma/all_ans
print(all_ans_tot)
print(np.argmax(all_ans_tot),np.max(all_ans_tot))

# %%
print(thick_gamma_cu)


orig=e_min_gamma_cu
n1=np.concatenate([[-999],e_min_gamma_cu[:-1]])
n2=np.concatenate([[-999,-999],e_min_gamma_cu[:-2]])
n3=np.concatenate([[-999,-999,-999],e_min_gamma_cu[:-3]])
n4=np.concatenate([[-999,-999,-999,-999],e_min_gamma_cu[:-4]])
n5=np.concatenate([[-999,-999,-999,-999,-999],e_min_gamma_cu[:-5]])
n6=np.concatenate([[-999,-999,-999,-999,-999,-999],e_min_gamma_cu[:-6]])
n7=np.concatenate([[-999,-999,-999,-999,-999,-999,-999],e_min_gamma_cu[:-7]])
n8=np.concatenate([[-999,-999,-999,-999,-999,-999,-999,-999],e_min_gamma_cu[:-8]])
print(orig)

a=np.array([1,2,4,9])
b=np.array([-99,1,2,4])
c=np.array([-99,-99,1,2])
d=np.array([-99,-99,-99,1])

combs=it.combinations([a,b,c,d],2)
# combs=it.combinations([orig,n1,n2,n3,n4,n3,n4,n5,n6,n7,n8],2)

# print(n3)
for comb in combs:
    a1=comb[0]-comb[1]
#     a1[a1>1000]=0
    print(a1)

# %% [markdown]
# # Alex and Jo ignore the next bit

# %%
filenames_e=[
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.00001peakStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.0001peakStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.001peakStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.01peakStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.1peakStepSize-Edep_v2.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-1.0peakStepSize-Edep_v2.root"

]


data_frame_dict={}
for files in filenames_e:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()

# %%
plt.subplots(1,1,figsize=(15,7))
e_min=np.array([])
thick=np.array([])
zero=data_frame_dict[filenames_e[0]][0][:,540:740].mean(axis=1)[50:150].mean()
e_min=np.append(e_min,zero)
thick=np.append(thick,0)

for files in filenames_e:
 
    dic=data_frame_dict[files][0][:,540:740].mean(axis=1)
    dic=dic.reshape(int(len(dic)/6),6).mean(axis=1)
    histe=plt.plot(dic,label=files[63:-16]+"um")
#     e_min=np.append(e_min,dic[250:370].mean())
#     thick=np.append(thick,int(files[63:-16]))

#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
filenames_e=[
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.00001airboxStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.0001airboxStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.001airboxStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.01airboxStepSize-Edep_v2.root",\
#             "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-0.1airboxStepSize-Edep_v2.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-400peakum-1.0airboxStepSize-Edep_v2.root"

]


data_frame_dict={}
for files in filenames_e:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()

# %%
plt.subplots(1,1,figsize=(15,7))
e_min=np.array([])
thick=np.array([])
zero=data_frame_dict[filenames_e[0]][0][:,540:740].mean(axis=1)[50:150].mean()
e_min=np.append(e_min,zero)
thick=np.append(thick,0)

for files in filenames_e:
 
    dic=data_frame_dict[files][0][:,540:740].mean(axis=1)
    dic=dic.reshape(int(len(dic)/6),6).mean(axis=1)
    histe=plt.plot(dic,label=files[63:-16]+"um")
#     e_min=np.append(e_min,dic[250:370].mean())
#     thick=np.append(thick,int(files[63:-16]))

#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
filenames_e=[
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-down-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-up-Edep.root"
]


data_frame_dict={}
for files in filenames_e:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()

# %%
plt.subplots(1,1,figsize=(15,7))
e_min=np.array([])
thick=np.array([])
zero=data_frame_dict[filenames_e[0]][0][540:740,:].mean(axis=0)[50:150].mean()
e_min=np.append(e_min,zero)
thick=np.append(thick,0)

for files in filenames_e:
 
    dic=data_frame_dict[files][0][540:740,:].mean(axis=0)
    dic=dic.reshape(int(len(dic)/12),12).mean(axis=1)
    histe=plt.plot(dic,label=files[63:-16]+"um")
#     e_min=np.append(e_min,dic[250:370].mean())
#     thick=np.append(thick,int(files[63:-16]))

#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
filenames_e=[
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-down-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-up-Silicon-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-down-Edep.root",\
            "/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Elec_Square_V3/Total-300peak1um_250peak2um_twopeaks-up-Edep.root"
]


data_frame_dict={}
for files in filenames_e:
    print(f"{files}   \n")
    data_frame_dict[files]=uproot.open(files)["histo"].numpy()

# %%
plt.subplots(1,1,figsize=(15,7))
e_min=np.array([])
thick=np.array([])
zero=data_frame_dict[filenames_e[0]][0][540:740,:].mean(axis=0)[50:150].mean()
e_min=np.append(e_min,zero)
thick=np.append(thick,0)

for files in filenames_e:
 
    dic=data_frame_dict[files][0][540:740,:].mean(axis=0)
    dic=dic.reshape(int(len(dic)/1),1).mean(axis=1)
    histe=plt.plot(dic,label=files[83:-10])
#     e_min=np.append(e_min,dic[250:370].mean())
#     thick=np.append(thick,int(files[63:-16]))

#     print(f'{dic[10:160].mean():.4f} {dic[250:370].mean():.4f} {dic[50:150].mean()-dic[250:370].mean():.4f}')



# plt.yscale('log')
plt.legend()
# plt.xlim(0,5.8)
# plt.ylim(0.001,1)
plt.show()

# %%
plt.subplots(1,1,figsize=(18,5))
# histy[0][400:601,:]
histy[0][490:511,:].mean(axis=0)
# plt.plot(histy[0][495:506,:].mean(axis=0),color='cyan')
plt.plot(histy[0][405:426,:].mean(axis=0),color='cyan')
plt.plot(histy[0][745:776,:].mean(axis=0),color='red')
# plt.plot(histy[0][95:106,:].mean(axis=0),color='red')

# %%
plt.subplots(1,1,figsize=(16,5))

plt.plot(histy[0][:,:].mean(axis=1),color='red')
# plt.xlim(100,900)
plt.ylim(11.0,11.3)

# %%
hist10x=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_10x10_Elec_Grating_X/Total-200files-Edep.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_y=hist10x[1][0]
plt.imshow(hist10x[0],extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]])

# %%
    hist10y=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_10x10_Elec_Grating_Y/Total-200files-Edep.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_10y=hist10y[1][0]
plt.imshow(hist10y[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]])
plt.colorbar()

# %%
hist10y_gamma=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Gamma_Grating_X_comptxsecbias100/Total-200files-Edep.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_10y_gamma=hist10y_gamma[1][0]
plt.imshow(hist10y_gamma[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]])
plt.colorbar()

# %%
fig,ax=plt.subplots(1,2,figsize=(16,7)) # histy[0][400:601,:]

cam=Camera(fig)
for i in range(0,991,10):
    hist_temp=hist10y_gamma[0].copy()
#     print(i,i+10)
    hist_temp[:,i:i+10]=hist_temp[:,i:i+10]*0.75
    ax[0].imshow(hist_temp,extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]])
    ax[1].plot(hist10y_gamma[0][:,i:i+10].mean(axis=1),color='blue')
#     plt.show()
    cam.snap()
a=cam.animate()
a.save("/home/lb8075/linac/gratingfilm_10y_gamma.mp4")

# %%
plt.subplots(1,1,figsize=(16,5))
# histy[0][400:601,:]
plt.plot(hist10y_gamma[0][:,450:550].mean(axis=1))
plt.plot(hist10y_gamma[0][:,50:150].mean(axis=1),color='red')

# %%
hist10y_gamma=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Gamma_Grating_X_comptxsecbias100/Total-200files-Edep.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_10y=hist10y_gamma[1][0]
plt.imshow(hist10y_gamma[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]])
plt.colorbar()

# %%
plt.subplots(1,1,figsize=(16,5))
# histy[0][400:601,:]
plt.plot(hist10y_gamma[0][:,450:550].mean(axis=1))
plt.plot(hist10y_gamma[0][:,50:150].mean(axis=1),color='red')
plt.xlim(200,800)

# %%
fig,ax=plt.subplots(1,2,figsize=(16,7)) # histy[0][400:601,:]

cam=Camera(fig)
for i in range(0,991,10):
    hist_temp=hist10y_gamma[0].copy()
#     print(i,i+10)
    hist_temp[:,i:i+10]=hist_temp[:,i:i+10]*0.75
    ax[0].imshow(hist_temp,extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]])
    ax[1].plot(hist10y_gamma[0][:,i:i+10].mean(axis=1),color='blue')
#     plt.show()
    cam.snap()
a=cam.animate()
a.save("/home/lb8075/linac/gratingfilm_10y_gamma.mp4")

# %%
fig,ax=plt.subplots(1,3,figsize=(18,7))
# hist2=hist[0].copy()
# hist2[:]=0
xy=hist[1][0]
ax[0].imshow(hist[0],extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]],vmax=100)
ax[1].imshow(2.89*hist10y_gamma[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]],vmax=100)
ax[2].imshow(hist[0]+2.89*hist10y_gamma[0],extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]],vmax=100)
print((2.89*hist10y_gamma[0]).max())
# plt.colorbar()

# %%
hist[0]

# %%
fig,ax=plt.subplots(1,2,figsize=(20,7)) # histy[0][400:601,:]

cam=Camera(fig)
for i in range(0,991,10):
    hist_temp=hist10y_gamma[0].copy()
#     print(i,i+10)
    hist_temp[:,i:i+10]=hist_temp[:,i:i+10]*0.75
    ax[0].imshow(hist_temp,extent=[xy[0][0],xy[0][-1],xy[1][0],xy[1][-1]],vmax=100)
    ax[1].plot(2.89*hist10y_gamma[0][:,i:i+10].mean(axis=1),color='red')
    ax[1].plot(hist[0][:,i:i+10].mean(axis=1),color='blue')
    ax[1].plot((hist[0]+2.89*hist10y_gamma[0])[:,i:i+10].mean(axis=1),color='green')
#     plt.show()
    cam.snap()
a=cam.animate()
a.save("/home/lb8075/linac/gratingfilm_10y_gamma.mp4")

# %%
hist10x_gamma=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Gamma_Grating_Y_comptxsecbias100/Total-200files-Edep.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_10y=hist10x_gamma[1][0]
plt.imshow(hist10x_gamma[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]])
plt.colorbar()

print(hist10x_gamma[0].max())

# %%
fig,ax=plt.subplots(1,2,figsize=(20,7)) # histy[0][400:601,:]

cam=Camera(fig)
for i in range(0,991,10):
    hist_temp=hist10x_gamma[0].copy()
#     print(i,i+10)
    hist_temp[i:i+10,:]=hist_temp[i:i+10,:]*0.75
    ax[0].imshow(hist_temp,extent=[xy_y[0][0],xy_y[0][-1],xy_y[1][0],xy_y[1][-1]],vmax=26)
    ax[1].plot(2.89*hist10x_gamma[0][i:i+10,:].mean(axis=0),color='red')
    ax[1].plot(histy[0][i:i+10,:].mean(axis=0),color='blue')
    ax[1].plot((histy[0]+2.89*hist10x_gamma[0])[i:i+10,:].mean(axis=0),color='green')
#     plt.show()
    cam.snap()
a=cam.animate()
a.save("/home/lb8075/linac/gratingfilm_10x_gamma.mp4")

# %%
hist10x_gamma=uproot.open("/work/lb8075/PhaseSpaces/PhS3BigSensor_40x40_Gamma_Grating_X_comptxsecbias100/Total-200files-Edep-400um.root")["histo"].numpy()
plt.subplots(1,1,figsize=(8,8))

xy_10y=hist10x_gamma[1][0]
plt.imshow(hist10x_gamma[0],extent=[xy_10y[0][0],xy_10y[0][-1],xy_10y[1][0],xy_10y[1][-1]])
plt.colorbar()

print(hist10x_gamma[0].max())

# %%
plt.subplots(1,1,figsize=(16,5))
# histy[0][400:601,:]
plt.plot(hist10x_gamma[0][:,450:550].mean(axis=1))
plt.plot(hist10x_gamma[0][:,50:150].mean(axis=1),color='red')
plt.xlim(200,800)
