# %%
import numpy as np

# %%
peak_z=1000000.0 #nm
PS_z=10000.0 #nm
epi_z=10000.0 #nm
start_pos=449995000.0 #nm
# peak_z=10.0 #nm
# PS_z=5.0 #nm
# epi_z=0.0 #nm
# start_pos=100.0 #nm

interval=(peak_z/2.0)+(PS_z/2.0)
transPS_z=start_pos+(epi_z/2.0)+(PS_z/2.0)
transPeak_z=start_pos+(epi_z/2.0)+(PS_z)+(peak_z/2.0)
print(interval)
for i in range(1,11):
    
    print("/gate/world/daughters/name         PSlayer"+str(i)+" \n"+ \
    "/gate/world/daughters/insert       box \n"+ \
    "/gate/PSlayer"+str(i)+"/setMaterial                  Silicon \n"+ \
    "/gate/PSlayer"+str(i)+"/geometry/setXLength          11.0 mm \n"+ \
    "/gate/PSlayer"+str(i)+"/geometry/setYLength          11.0 mm \n"+ \
    "/gate/PSlayer"+str(i)+"/geometry/setZLength          "+str(PS_z)+" nm \n"+ \
    "/gate/PSlayer"+str(i)+"/placement/setTranslation     0 0 "+str(transPS_z)+" nm \n"+ \
    "/gate/PSlayer"+str(i)+"/vis/setVisible               1 \n"+ \
    "/gate/PSlayer"+str(i)+"/vis/setColor                 blue\n"+
    "/gate/PSlayer"+str(i)+"/vis/forceSolid\n")    
    
    print("/gate/world/daughters/name         peakLayer"+str(i)+" \n"+ \
    "/gate/world/daughters/insert       box \n"+ \
    "/gate/peakLayer"+str(i)+"/setMaterial                  Silicon \n"+ \
    "/gate/peakLayer"+str(i)+"/geometry/setXLength          5.0 mm \n"+ \
    "/gate/peakLayer"+str(i)+"/geometry/setYLength          5.0 mm \n"+ \
    "/gate/peakLayer"+str(i)+"/geometry/setZLength          "+str(peak_z)+" nm \n"+ \
    "/gate/peakLayer"+str(i)+"/placement/setTranslation     0 0 "+str(transPeak_z)+" nm \n"+ \
    "/gate/peakLayer"+str(i)+"/vis/setVisible               1 \n"+ \
    "/gate/peakLayer"+str(i)+"/vis/setColor                 grey\n"+
    "/gate/peakLayer"+str(i)+"/vis/forceSolid\n")

    
    transPS_z=transPeak_z+interval
    transPeak_z=transPS_z+interval
# Out:
# 505000.0
# /gate/world/daughters/name         PSlayer1
# /gate/world/daughters/insert       box
# /gate/PSlayer1/setMaterial                  Silicon
# /gate/PSlayer1/geometry/setXLength          11.0 mm
# /gate/PSlayer1/geometry/setYLength          11.0 mm
# /gate/PSlayer1/geometry/setZLength          10000.0 nm
# /gate/PSlayer1/placement/setTranslation     0 0 450005000.0 nm
# /gate/PSlayer1/vis/setVisible               1
# /gate/PSlayer1/vis/setColor                 blue
# /gate/PSlayer1/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer1
# /gate/world/daughters/insert       box
# /gate/peakLayer1/setMaterial                  Silicon
# /gate/peakLayer1/geometry/setXLength          5.0 mm
# /gate/peakLayer1/geometry/setYLength          5.0 mm
# /gate/peakLayer1/geometry/setZLength          1000000.0 nm
# /gate/peakLayer1/placement/setTranslation     0 0 450510000.0 nm
# /gate/peakLayer1/vis/setVisible               1
# /gate/peakLayer1/vis/setColor                 grey
# /gate/peakLayer1/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer2
# /gate/world/daughters/insert       box
# /gate/PSlayer2/setMaterial                  Silicon
# /gate/PSlayer2/geometry/setXLength          11.0 mm
# /gate/PSlayer2/geometry/setYLength          11.0 mm
# /gate/PSlayer2/geometry/setZLength          10000.0 nm
# /gate/PSlayer2/placement/setTranslation     0 0 451015000.0 nm
# /gate/PSlayer2/vis/setVisible               1
# /gate/PSlayer2/vis/setColor                 blue
# /gate/PSlayer2/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer2
# /gate/world/daughters/insert       box
# /gate/peakLayer2/setMaterial                  Silicon
# /gate/peakLayer2/geometry/setXLength          5.0 mm
# /gate/peakLayer2/geometry/setYLength          5.0 mm
# /gate/peakLayer2/geometry/setZLength          1000000.0 nm
# /gate/peakLayer2/placement/setTranslation     0 0 451520000.0 nm
# /gate/peakLayer2/vis/setVisible               1
# /gate/peakLayer2/vis/setColor                 grey
# /gate/peakLayer2/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer3
# /gate/world/daughters/insert       box
# /gate/PSlayer3/setMaterial                  Silicon
# /gate/PSlayer3/geometry/setXLength          11.0 mm
# /gate/PSlayer3/geometry/setYLength          11.0 mm
# /gate/PSlayer3/geometry/setZLength          10000.0 nm
# /gate/PSlayer3/placement/setTranslation     0 0 452025000.0 nm
# /gate/PSlayer3/vis/setVisible               1
# /gate/PSlayer3/vis/setColor                 blue
# /gate/PSlayer3/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer3
# /gate/world/daughters/insert       box
# /gate/peakLayer3/setMaterial                  Silicon
# /gate/peakLayer3/geometry/setXLength          5.0 mm
# /gate/peakLayer3/geometry/setYLength          5.0 mm
# /gate/peakLayer3/geometry/setZLength          1000000.0 nm
# /gate/peakLayer3/placement/setTranslation     0 0 452530000.0 nm
# /gate/peakLayer3/vis/setVisible               1
# /gate/peakLayer3/vis/setColor                 grey
# /gate/peakLayer3/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer4
# /gate/world/daughters/insert       box
# /gate/PSlayer4/setMaterial                  Silicon
# /gate/PSlayer4/geometry/setXLength          11.0 mm
# /gate/PSlayer4/geometry/setYLength          11.0 mm
# /gate/PSlayer4/geometry/setZLength          10000.0 nm
# /gate/PSlayer4/placement/setTranslation     0 0 453035000.0 nm
# /gate/PSlayer4/vis/setVisible               1
# /gate/PSlayer4/vis/setColor                 blue
# /gate/PSlayer4/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer4
# /gate/world/daughters/insert       box
# /gate/peakLayer4/setMaterial                  Silicon
# /gate/peakLayer4/geometry/setXLength          5.0 mm
# /gate/peakLayer4/geometry/setYLength          5.0 mm
# /gate/peakLayer4/geometry/setZLength          1000000.0 nm
# /gate/peakLayer4/placement/setTranslation     0 0 453540000.0 nm
# /gate/peakLayer4/vis/setVisible               1
# /gate/peakLayer4/vis/setColor                 grey
# /gate/peakLayer4/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer5
# /gate/world/daughters/insert       box
# /gate/PSlayer5/setMaterial                  Silicon
# /gate/PSlayer5/geometry/setXLength          11.0 mm
# /gate/PSlayer5/geometry/setYLength          11.0 mm
# /gate/PSlayer5/geometry/setZLength          10000.0 nm
# /gate/PSlayer5/placement/setTranslation     0 0 454045000.0 nm
# /gate/PSlayer5/vis/setVisible               1
# /gate/PSlayer5/vis/setColor                 blue
# /gate/PSlayer5/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer5
# /gate/world/daughters/insert       box
# /gate/peakLayer5/setMaterial                  Silicon
# /gate/peakLayer5/geometry/setXLength          5.0 mm
# /gate/peakLayer5/geometry/setYLength          5.0 mm
# /gate/peakLayer5/geometry/setZLength          1000000.0 nm
# /gate/peakLayer5/placement/setTranslation     0 0 454550000.0 nm
# /gate/peakLayer5/vis/setVisible               1
# /gate/peakLayer5/vis/setColor                 grey
# /gate/peakLayer5/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer6
# /gate/world/daughters/insert       box
# /gate/PSlayer6/setMaterial                  Silicon
# /gate/PSlayer6/geometry/setXLength          11.0 mm
# /gate/PSlayer6/geometry/setYLength          11.0 mm
# /gate/PSlayer6/geometry/setZLength          10000.0 nm
# /gate/PSlayer6/placement/setTranslation     0 0 455055000.0 nm
# /gate/PSlayer6/vis/setVisible               1
# /gate/PSlayer6/vis/setColor                 blue
# /gate/PSlayer6/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer6
# /gate/world/daughters/insert       box
# /gate/peakLayer6/setMaterial                  Silicon
# /gate/peakLayer6/geometry/setXLength          5.0 mm
# /gate/peakLayer6/geometry/setYLength          5.0 mm
# /gate/peakLayer6/geometry/setZLength          1000000.0 nm
# /gate/peakLayer6/placement/setTranslation     0 0 455560000.0 nm
# /gate/peakLayer6/vis/setVisible               1
# /gate/peakLayer6/vis/setColor                 grey
# /gate/peakLayer6/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer7
# /gate/world/daughters/insert       box
# /gate/PSlayer7/setMaterial                  Silicon
# /gate/PSlayer7/geometry/setXLength          11.0 mm
# /gate/PSlayer7/geometry/setYLength          11.0 mm
# /gate/PSlayer7/geometry/setZLength          10000.0 nm
# /gate/PSlayer7/placement/setTranslation     0 0 456065000.0 nm
# /gate/PSlayer7/vis/setVisible               1
# /gate/PSlayer7/vis/setColor                 blue
# /gate/PSlayer7/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer7
# /gate/world/daughters/insert       box
# /gate/peakLayer7/setMaterial                  Silicon
# /gate/peakLayer7/geometry/setXLength          5.0 mm
# /gate/peakLayer7/geometry/setYLength          5.0 mm
# /gate/peakLayer7/geometry/setZLength          1000000.0 nm
# /gate/peakLayer7/placement/setTranslation     0 0 456570000.0 nm
# /gate/peakLayer7/vis/setVisible               1
# /gate/peakLayer7/vis/setColor                 grey
# /gate/peakLayer7/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer8
# /gate/world/daughters/insert       box
# /gate/PSlayer8/setMaterial                  Silicon
# /gate/PSlayer8/geometry/setXLength          11.0 mm
# /gate/PSlayer8/geometry/setYLength          11.0 mm
# /gate/PSlayer8/geometry/setZLength          10000.0 nm
# /gate/PSlayer8/placement/setTranslation     0 0 457075000.0 nm
# /gate/PSlayer8/vis/setVisible               1
# /gate/PSlayer8/vis/setColor                 blue
# /gate/PSlayer8/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer8
# /gate/world/daughters/insert       box
# /gate/peakLayer8/setMaterial                  Silicon
# /gate/peakLayer8/geometry/setXLength          5.0 mm
# /gate/peakLayer8/geometry/setYLength          5.0 mm
# /gate/peakLayer8/geometry/setZLength          1000000.0 nm
# /gate/peakLayer8/placement/setTranslation     0 0 457580000.0 nm
# /gate/peakLayer8/vis/setVisible               1
# /gate/peakLayer8/vis/setColor                 grey
# /gate/peakLayer8/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer9
# /gate/world/daughters/insert       box
# /gate/PSlayer9/setMaterial                  Silicon
# /gate/PSlayer9/geometry/setXLength          11.0 mm
# /gate/PSlayer9/geometry/setYLength          11.0 mm
# /gate/PSlayer9/geometry/setZLength          10000.0 nm
# /gate/PSlayer9/placement/setTranslation     0 0 458085000.0 nm
# /gate/PSlayer9/vis/setVisible               1
# /gate/PSlayer9/vis/setColor                 blue
# /gate/PSlayer9/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer9
# /gate/world/daughters/insert       box
# /gate/peakLayer9/setMaterial                  Silicon
# /gate/peakLayer9/geometry/setXLength          5.0 mm
# /gate/peakLayer9/geometry/setYLength          5.0 mm
# /gate/peakLayer9/geometry/setZLength          1000000.0 nm
# /gate/peakLayer9/placement/setTranslation     0 0 458590000.0 nm
# /gate/peakLayer9/vis/setVisible               1
# /gate/peakLayer9/vis/setColor                 grey
# /gate/peakLayer9/vis/forceSolid
#
# /gate/world/daughters/name         PSlayer10
# /gate/world/daughters/insert       box
# /gate/PSlayer10/setMaterial                  Silicon
# /gate/PSlayer10/geometry/setXLength          11.0 mm
# /gate/PSlayer10/geometry/setYLength          11.0 mm
# /gate/PSlayer10/geometry/setZLength          10000.0 nm
# /gate/PSlayer10/placement/setTranslation     0 0 459095000.0 nm
# /gate/PSlayer10/vis/setVisible               1
# /gate/PSlayer10/vis/setColor                 blue
# /gate/PSlayer10/vis/forceSolid
#
# /gate/world/daughters/name         peakLayer10
# /gate/world/daughters/insert       box
# /gate/peakLayer10/setMaterial                  Silicon
# /gate/peakLayer10/geometry/setXLength          5.0 mm
# /gate/peakLayer10/geometry/setYLength          5.0 mm
# /gate/peakLayer10/geometry/setZLength          1000000.0 nm
# /gate/peakLayer10/placement/setTranslation     0 0 459600000.0 nm
# /gate/peakLayer10/vis/setVisible               1
# /gate/peakLayer10/vis/setColor                 grey
# /gate/peakLayer10/vis/forceSolid
