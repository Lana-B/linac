# %%
import numpy as np
import math
from matplotlib import pylab as plt
# from ROOT import TTree, TFile, TH2D, TCanvas, TH1F, gROOT
# from root_numpy import array2hist, hist2array, fill_hist, tree2array, root2array, list_trees
import pandas as pd
# from root_pandas import read_root
# import uproot
import time

# %%
df5e = pd.read_pickle("electron5x5.pkl")
print("read")
df5g = pd.read_pickle("../PhS2_5x5/Gamma5x5.pkl")
print("read")
df10e = pd.read_pickle("electron10x10.pkl")
print("read")
df10g = pd.read_pickle("../PhS2_10x10/Gamma10x10.pkl")
print("read")
df20e = pd.read_pickle("electron20x20.pkl")
print("read")
df20g = pd.read_pickle("../PhS2_20x20/Gamma20x20.pkl")
print("read")
# Out:
# read
# read
# read
# read
# read
# read

# %%
df5e
# Out:
#                  X          Y        dX        dY    Weight     Ekine
# 0         7.390625  -0.467041  0.700195  0.396729  0.000400  0.055756
# 1        13.757812 -17.531250  0.079468 -0.686523  0.000400  0.186523
# 2        23.281250   5.566406  0.132568 -0.247070  0.000400  0.176758
# 3        19.875000 -23.421875  0.391846 -0.149780  0.000400  0.051941
# 4       -50.218750  -6.253906 -0.570312  0.168823  0.000008  0.631348
# ...            ...        ...       ...       ...       ...       ...
# 3162272  -2.847656  12.664062 -0.257080  0.237915  0.000008  1.044922
# 3162273  38.968750   4.367188  0.239990  0.195557  0.000008  0.910156
# 3162274  47.718750   2.541016  0.327148  0.055481  0.000008  1.312500
# 3162275   2.173828   2.523438  0.018173 -0.345215  0.000400  0.921387
# 3162276  19.937500   0.699707  0.367676 -0.267578  0.000400  0.755371
#
# [3162277 rows x 6 columns]

# %%
_=plt.hist(df5e['Weight'],bins=100,range=(0,0.0003))
plt.xlim(0,0.0003)
# Out:
# (0, 0.0003)

# %%
_=plt.hist(df5g['Weight'],bins=100)

# %%
fig,ax=plt.subplots(2,3,figsize=(14,8))
hist5e=ax[0,0].hist2d(df5e['X'],df5e['Y'],bins=(60,60),weights=df5e["Weight"])
fig.colorbar(mappable=hist5e[3], ax=ax[0,0]) 
print("plot1")

hist5g=ax[1,0].hist2d(df5g['X'],df5g['Y'],bins=(60,60),weights=df5g["Weight"])
fig.colorbar(mappable=hist5g[3], ax=ax[1,0]) 

print("plot2")
hist10e=ax[0,1].hist2d(df10e['X'],df10e['Y'],bins=(60,60),weights=df10e["Weight"])
fig.colorbar(mappable=hist10e[3], ax=ax[0,1]) 

print("plot3")
hist10g=ax[1,1].hist2d(df10g['X'],df10g['Y'],bins=(60,60),weights=df10g["Weight"])
fig.colorbar(mappable=hist10g[3], ax=ax[1,1]) 

print("plot4")
hist20e=ax[0,2].hist2d(df20e['X'],df20e['Y'],bins=(60,60),weights=df20e["Weight"])
fig.colorbar(mappable=hist20e[3], ax=ax[0,2]) 

print("plot5")
hist20g=ax[1,2].hist2d(df20g['X'],df20g['Y'],bins=(60,60),weights=df20g["Weight"])
fig.colorbar(mappable=hist20g[3], ax=ax[1,2]) 

print("plot6")
# Out:
# plot1
# plot2
# plot3
# plot4
# plot5
# plot6

# %%
plt.hist2d(df20e['X'],df20e['Y'],bins=(60,60),range=((-10,10),(-10,10)),weights=df20e["Weight"])
plt.colorbar()

# %%
df20e[(abs(df20e['X'])<10)&(abs(df20e['Y'])<10)]
# Out:
#                  X         Y        dX        dY    Weight     Ekine
# 1         0.071716 -3.050781  0.375244 -0.790039  0.000400  1.047852
# 141       5.406250 -4.617188  0.469971  0.559082  0.000400  0.341064
# 156       1.640625 -0.772949  0.135864  0.249390  0.000400  0.463379
# 230      -3.173828 -3.761719 -0.197144  0.029297  0.000400  2.115234
# 263      -3.976562 -6.960938 -0.113708  0.041473  0.000400  1.596680
# ...            ...       ...       ...       ...       ...       ...
# 45957879 -1.001953 -2.519531 -0.425537 -0.396973  0.000400  2.394531
# 45957894  9.640625  1.715820 -0.179443 -0.027863  0.000400  2.380859
# 45957924  5.480469 -1.083984 -0.137207 -0.010490  0.000400  0.977051
# 45957983  6.363281 -1.911133  0.351562  0.386963  0.000400  1.225586
# 45958020 -5.523438 -2.148438  0.184814 -0.350830  0.000008  0.566895
#
# [1521679 rows x 6 columns]

# %%
plt.hist2d(df5e['X'],df5e['Y'],bins=(10,10),range=((-10,10),(-10,10)))
plt.colorbar()
df5e[(abs(df5e['X'])<10)&(abs(df5e['Y'])<10)]
# Out:
#                 X         Y        dX        dY    Weight     Ekine
# 0        7.390625 -0.467041  0.700195  0.396729  0.000400  0.055756
# 12      -1.227539  0.554688 -0.690430 -0.151978  0.020004  0.208374
# 18       3.460938  7.671875 -0.544434  0.019043  0.000400  0.321533
# 19       2.953125 -7.382812 -0.205322 -0.559082  0.000400  0.576660
# 22       4.726562 -6.820312 -0.209717 -0.684570  0.000400  0.600098
# ...           ...       ...       ...       ...       ...       ...
# 3162249 -5.578125 -4.570312  0.219360  0.196655  0.000400  1.495117
# 3162254  4.308594  4.468750  0.117676  0.143677  0.000400  3.310547
# 3162260 -1.797852  5.542969  0.033875 -0.208008  0.000400  0.717773
# 3162267 -2.490234  0.350586  0.313477  0.020767  0.000400  0.092163
# 3162275  2.173828  2.523438  0.018173 -0.345215  0.000400  0.921387
#
# [544216 rows x 6 columns]

# %%
hist5e=np.array(hist5e[0])

# %%
hist10e=np.array(hist10e[0])
hist20e=np.array(hist20e[0])

# %%
hist5e.shape
# Out:
# (60, 60)

# %%
plt.plot(hist5e[28:33,:].mean(axis=0))
plt.plot(hist10e[28:33,:].mean(axis=0),color="red")
plt.plot(hist20e[28:33,:].mean(axis=0),color="green")
plt.xlabel("X (cm)")
# Out:
# Text(0.5, 0, 'X (cm)')

# %%
hist5g=np.array(hist5g[0])
hist10g=np.array(hist10g[0])
hist20g=np.array(hist20g[0])

# %%
plt.plot(hist5g[28:33,:].mean(axis=0))
plt.plot(hist10g[28:33,:].mean(axis=0),color="red")
plt.plot(hist20g[28:33,:].mean(axis=0),color="green")

# %%
hist5govere=hist5g/hist5e

# %%
hist10govere=hist10g/hist10e
hist20govere=hist20g/hist20e

# %%
plt.plot(hist5govere[28:33,:].mean(axis=0))
plt.plot(hist10govere[28:33,:].mean(axis=0),color="red")
plt.plot(hist20govere[28:33,:].mean(axis=0),color="green")

# %%
df5e['dZ']=pow(1.0-df5e['dX']*df5e['dX']-df5e['dY']*df5e['dY'],0.5)
df10e['dZ']=pow(1.0-df10e['dX']*df10e['dX']-df10e['dY']*df10e['dY'],0.5)
df20e['dZ']=pow(1.0-df20e['dX']*df20e['dX']-df20e['dY']*df20e['dY'],0.5)
df5g['dZ']=pow(1.0-df5g['dX']*df5g['dX']-df5g['dY']*df5g['dY'],0.5)
df10g['dZ']=pow(1.0-df10g['dX']*df10g['dX']-df10g['dY']*df10g['dY'],0.5)
df20g['dZ']=pow(1.0-df20g['dX']*df20g['dX']-df20g['dY']*df20g['dY'],0.5)

# %%
df5e['dXdY']=(df5e.dX**2+df5e.dY**2)**0.5
df5g['dXdY']=(df5g.dX**2+df5g.dY**2)**0.5
df10e['dXdY']=(df10e.dX**2+df10e.dY**2)**0.5
df10g['dXdY']=(df10g.dX**2+df10g.dY**2)**0.5
df20e['dXdY']=(df20e.dX**2+df20e.dY**2)**0.5
df20g['dXdY']=(df20g.dX**2+df20g.dY**2)**0.5

# %%
# ratioThetaXYe=dfe.dXdY/dfe.dZ
# ratioThetaXe=df5e.dX/df5e.dZ
# ratioThetaYe=dfe.dX/dfe.dZ

# ratioThetaXYg=dfg.dXdY/dfg.dZ
# ratioThetaXg=dfg.dX/dfg.dZ
# ratioThetaYg=dfg.dX/dfg.dZ

# ratioThetaXY_2e=df_2e.dXdY/df_2e.dZ
# ratioThetaX_2e=df_2e.dX/df_2e.dZ
# ratioThetaY_2e=df_2e.dX/df_2e.dZ

# ratioThetaXY_2g=df_2g.dXdY/df_2g.dZ
# ratioThetaX_2g=df_2g.dX/df_2g.dZ
# ratioThetaY_2g=df_2g.dX/df_2g.dZ


ratioThetaX5e=df5e.dX/df5e.dZ
ratioThetaX10e=df10e.dX/df10e.dZ
ratioThetaX20e=df20e.dX/df20e.dZ

ratioThetaY5e=df5e.dY/df5e.dZ
ratioThetaY10e=df10e.dY/df10e.dZ
ratioThetaY20e=df20e.dY/df20e.dZ

# %%
# dfe['thetaXY']=ratioThetaXYe.apply(math.atan)*180/3.14
# dfe['thetaX']=ratioThetaXe.apply(math.atan)*180/3.14
# dfe['thetaY']=ratioThetaYe.apply(math.atan)*180/3.14

# dfg['thetaXY']=ratioThetaXYg.apply(math.atan)*180/3.14
# dfg['thetaX']=ratioThetaXg.apply(math.atan)*180/3.14
# dfg['thetaY']=ratioThetaYg.apply(math.atan)*180/3.14

# df_2e['thetaXY']=ratioThetaXY_2e.apply(math.atan)*180/3.14
# df_2e['thetaX']=ratioThetaX_2e.apply(math.atan)*180/3.14
# df_2e['thetaY']=ratioThetaY_2e.apply(math.atan)*180/3.14

# df_2g['thetaXY']=ratioThetaXY_2g.apply(math.atan)*180/3.14
# df_2g['thetaX']=ratioThetaX_2g.apply(math.atan)*180/3.14
# df_2g['thetaY']=ratioThetaY_2g.apply(math.atan)*180/3.14

df5e['thetaX']=ratioThetaX5e.apply(math.atan)*180/3.14
df10e['thetaX']=ratioThetaX10e.apply(math.atan)*180/3.14
df20e['thetaX']=ratioThetaX20e.apply(math.atan)*180/3.14
df5e['thetaY']=ratioThetaY5e.apply(math.atan)*180/3.14
df10e['thetaY']=ratioThetaY10e.apply(math.atan)*180/3.14
df20e['thetaY']=ratioThetaY20e.apply(math.atan)*180/3.14

# %%
_=plt.hist(df5e['thetaX'],weights=df5e['Weight'],bins=200,histtype=u'step',density=True)
_=plt.hist(df10e['thetaX'],weights=df10e['Weight'],bins=200,histtype=u'step',color='red',density=True)
_=plt.hist(df20e['thetaX'],weights=df20e['Weight'],bins=200,histtype=u'step',color='green',density=True)

# %%
_=plt.hist(df5e['thetaY'],weights=df5e['Weight'],bins=200,histtype=u'step',density=True)
_=plt.hist(df10e['thetaY'],weights=df10e['Weight'],bins=200,histtype=u'step',color='red',density=True)
_=plt.hist(df20e['thetaY'],weights=df20e['Weight'],bins=200,histtype=u'step',color='green',density=True)

# %%
_=plt.hist(abs(df5e[abs(df5e['X'])<2]['thetaX']),weights=df5e[abs(df5e['X'])<2]['Weight'],bins=100,histtype=u'step',density=True)
_=plt.hist(abs(df10e[abs(df10e['X'])<2]['thetaX']),weights=df10e[abs(df10e['X'])<2]['Weight'],bins=100,histtype=u'step',color='red',density=True)
_=plt.hist(abs(df20e[abs(df20e['X'])<2]['thetaX']),weights=df20e[abs(df20e['X'])<2]['Weight'],bins=100,histtype=u'step',color='green',density=True)
plt.xlabel("X angle degrees")
# Out:
# Text(0.5, 0, 'X angle degrees')

# %%
_=plt.hist(abs(df20e[abs(df20e['X'])<2]['thetaX']),weights=df20e[abs(df20e['X'])<2]['Weight'],bins=100,histtype=u'step',color='red',density=True)
_=plt.hist(abs(df20e[(abs(df20e['X'])>40)&(abs(df20e['X'])<45)]['thetaX']),weights=df20e[(abs(df20e['X'])>40)&(abs(df20e['X'])<45)]['Weight'],bins=100,histtype=u'step',color='green',density=True)
plt.xlabel("X angle degrees")
# Out:
# Text(0.5, 0, 'X angle degrees')

# %%
_=plt.hist(abs(df5e[abs(df5e['X'])>60]['thetaX']),bins=100,histtype=u'step',density=True)
_=plt.hist(abs(df10e[abs(df10e['X'])>60]['thetaX']),bins=100,histtype=u'step',color='red',density=True)
_=plt.hist(abs(df20e[abs(df20e['X'])>60]['thetaX']),bins=100,histtype=u'step',color='green',density=True)
plt.xlabel("X angle degrees")
# Out:
# Text(0.5, 0, 'X angle degrees')

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))

subdf5e=df5e[(abs(df5e['Y']<10))&(df5e['Weight']>0.000006)][['X','Weight']]
subdf5g=df5g[(abs(df5g['Y']<10))&(df5g['Weight']>0.000006)][['X','Weight']]
subdf5g=subdf5g.astype('float32')

_=ax[0].hist(subdf5e['X'],weights=subdf5e['Weight'],bins=80,histtype=u'step')
# _=ax[0].hist(subdf5g['X'],weights=subdf5g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[0].set_xlabel('X (mm)')

subdf5e=df5e[(abs(df5e['X']<10))&(df5e['Weight']>0.000006)][['Y','Weight']]
subdf5g=df5g[(abs(df5g['X']<10))&(df5g['Weight']>0.000006)][['Y','Weight']]
subdf5g=subdf5g.astype('float32')


_=ax[1].hist(subdf5e['Y'],weights=subdf5e['Weight'],bins=80,histtype=u'step')
# _=ax[1].hist(subdf5g['Y'],weights=subdf5g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[1].set_xlabel('Y (mm)')
# Out:
# Text(0.5, 0, 'Y (mm)')

# %%
# fig,ax=plt.subplots(1,2,figsize=(12,4))

subdf5e=df5e[(abs(df5e['Y']<10))&(df5e['Weight']>0.000006)][['X','Weight']]
# subdf5g=df5g[(abs(df5g['Y']<10))&(df5g['Weight']>0.000006)][['X','Weight']]
subdf5g=subdf5g.astype('float32')

_=plt.hist(subdf5e['X'],weights=subdf5e['Weight'],bins=80,histtype=u'step')
# _=ax[0].hist(subdf5g['X'],weights=subdf5g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
# ax[0].set_xlabel('X (mm)')

subdf5e=df5e[(abs(df5e['X']<10))&(df5e['Weight']>0.000006)][['Y','Weight']]
# subdf5g=df5g[(abs(df5g['X']<10))&(df5g['Weight']>0.000006)][['Y','Weight']]
# subdf5g=subdf5g.astype('float32')


_=plt.hist(subdf5e['Y'],weights=subdf5e['Weight'],bins=80,histtype=u'step')
# _=ax[1].hist(subdf5g['Y'],weights=subdf5g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
# ax[1].set_xlabel('Y (mm)')

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))

subdf10e=df10e[(abs(df10e['Y']<10))&(df10e['Weight']>0.000006)][['X','Weight']]
subdf10g=df10g[(abs(df10g['Y']<10))&(df10g['Weight']>0.000006)][['X','Weight']]
subdf10g=subdf10g.astype('float32')

_=ax[0].hist(subdf10e['X'],weights=subdf10e['Weight'],bins=80,histtype=u'step',density=True)
_=ax[0].hist(subdf10g['X'],weights=subdf10g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[0].set_xlabel('X (mm)')

subdf10e=df10e[(abs(df10e['X']<10))&(df10e['Weight']>0.000006)][['Y','Weight']]
subdf10g=df10g[(abs(df10g['X']<10))&(df10g['Weight']>0.000006)][['Y','Weight']]
subdf10g=subdf10g.astype('float32')


_=ax[1].hist(subdf10e['Y'],weights=subdf10e['Weight'],bins=80,histtype=u'step',density=True)
_=ax[1].hist(subdf10g['Y'],weights=subdf10g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[1].set_xlabel('Y (mm)')
# Out:
# Text(0.5, 0, 'Y (mm)')

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))

subdf20e=df20e[(abs(df20e['Y']<10))&(df20e['Weight']>0.000006)][['X','Weight']]
subdf20g=df20g[(abs(df20g['Y']<10))&(df20g['Weight']>0.000006)][['X','Weight']]
subdf20g=subdf20g.astype('float32')

_=ax[0].hist(subdf20e['X'],weights=subdf20e['Weight'],bins=80,histtype=u'step',density=True)
_=ax[0].hist(subdf20g['X'],weights=subdf20g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[0].set_xlabel('X (mm)')

subdf20e=df20e[(abs(df20e['X']<10))&(df20e['Weight']>0.000006)][['Y','Weight']]
subdf20g=df20g[(abs(df20g['X']<10))&(df20g['Weight']>0.000006)][['Y','Weight']]
subdf20g=subdf20g.astype('float32')


_=ax[1].hist(subdf20e['Y'],weights=subdf20e['Weight'],bins=80,histtype=u'step',density=True)
_=ax[1].hist(subdf20g['Y'],weights=subdf20g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)
ax[1].set_xlabel('Y (mm)')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-310-db232a46aa4a> in <module>
#      10
#      11 subdf20e=df20e[(abs(df20e['X']<10))&(df20e['Weight']>0.000006)][['Y','Weight']]
# ---> 12 subdf20g=df20g[(abs(df20g['X']<10))&(df20g['Weight']>0.000006)][['Y','Weight']]
#      13 subdf20g=subdf20g.astype('float32')
#      14
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2843         key = check_bool_indexer(self.index, key)
# ...

# %%
subdf5e=df5e[(abs(df5e['X']<10))&(df5e['Weight']>0.000006)][['Y','Weight']]
subdf5g=df5g[(abs(df5g['X']<10))&(df5g['Weight']>0.000006)][['Y','Weight']]
subdf5g=subdf5g.astype('float32')


_=plt.hist(subdf5e['Y'],weights=subdf5e['Weight'],bins=80,histtype=u'step',density=True)
_=plt.hist(subdf5g['Y'],weights=subdf5g['Weight'],bins=80,histtype=u'step',color="cyan",density=True)

# %%
x_vals=5
y_vals=5
fig,ax=plt.subplots(y_vals,x_vals,figsize=(14,14),sharex=True,sharey=True)

for i in range(0,y_vals):
    for j in range(0,x_vals):
        y_start=i*5
        y_end=(i+1)*5
        x_start=j*5
        x_end=(j+1)*5
#         print(i,j,y_start,y_end,x_start,x_end)
        _=ax[i,j].hist(abs(df5e[(abs(df5e['Y'])>y_start)&(abs(df5e['X'])>x_start)&(abs(df5e['Y'])<y_end)&(abs(df5e['X'])<x_end)]['thetaX']),weights=df5e[(abs(df5e['Y'])>y_start)&(abs(df5e['X'])>x_start)&(abs(df5e['Y'])<y_end)&(abs(df5e['X'])<x_end)]['Weight'],bins=40,histtype=u'step',density=True)

# %%
x_vals=5
y_vals=5
fig,ax=plt.subplots(y_vals,x_vals,figsize=(14,14),sharex=True,sharey=True)

for i in range(0,y_vals):
    for j in range(0,x_vals):
        y_start=i*10
        y_end=(i+1)*10
        x_start=j*10
        x_end=(j+1)*10
#         print(i,j,y_start,y_end,x_start,x_end)
        _=ax[i,j].hist(abs(df20e[(abs(df20e['Y'])>y_start)&(abs(df20e['X'])>x_start)&(abs(df20e['Y'])<y_end)&(abs(df20e['X'])<x_end)]['thetaX']),weights=df20e[(abs(df20e['Y'])>y_start)&(abs(df20e['X'])>x_start)&(abs(df20e['Y'])<y_end)&(abs(df20e['X'])<x_end)]['Weight'],bins=40,histtype=u'step',density=True)

# %%
x_vals=5
y_vals=5
fig,ax=plt.subplots(y_vals,x_vals,figsize=(10,10),sharex=True,sharey=True)

for i in range(0,y_vals):
    for j in range(0,x_vals):
        y_start=i*5
        y_end=(i+1)*5
        x_start=j*5
        x_end=(j+1)*5
#         print(i,j,y_start,y_end,x_start,x_end)
        _=ax[i,j].hist(abs(df5e[(abs(df5e['Y'])>y_start)&(abs(df5e['X'])>x_start)&(abs(df5e['Y'])<y_end)&(abs(df5e['X'])<x_end)]['thetaY']),weights=df5e[(abs(df5e['Y'])>y_start)&(abs(df5e['X'])>x_start)&(abs(df5e['Y'])<y_end)&(abs(df5e['X'])<x_end)]['Weight'],bins=30,histtype=u'step',density=True)

# %%
x_vals=5
y_vals=5
fig,ax=plt.subplots(y_vals,x_vals,figsize=(10,10),sharex=True,sharey=True)

for i in range(0,y_vals):
    for j in range(0,x_vals):
        y_start=i*5
        y_end=(i+1)*5
        x_start=j*5
        x_end=(j+1)*5
#         print(i,j,y_start,y_end,x_start,x_end)
        _=ax[i,j].hist(abs(df5e[(abs(df5e['Y'])>y_start)&(abs(df5e['X'])>x_start)&(abs(df5e['Y'])<y_end)&(abs(df5e['X'])<x_end)]['thetaX']),bins=40,histtype=u'step',density=True,color="red")

# %%
_=plt.hist(df10e[df10e['Y']<10]['X'],bins=100,histtype=u'step',density=True)
_=plt.hist(df10g[df10g['Y']<10]['X'],bins=100,histtype=u'step',color="cyan",density=True)

# %%
_=plt.hist(df10e[df10e['X']<10]['Y'],bins=100,histtype=u'step',density=True)
_=plt.hist(df10g[df10g['X']<10]['Y'],bins=100,histtype=u'step',color="cyan",density=True)

# %%
_=plt.hist(df20e[df20e['Y']<10]['X'],bins=100,histtype=u'step',density=True)
_=plt.hist(df20g[df20g['Y']<10]['X'],bins=100,histtype=u'step',color="cyan",density=True)

# %%
_=plt.hist(df20e[df20e['X']<10]['Y'],bins=100,histtype=u'step',density=True)
_=plt.hist(df20g[df20g['X']<10]['Y'],bins=100,histtype=u'step',color="cyan",density=True)

# %%
# plt.subplots(1,2,figsize=(8,4))
_=plt.hist(df5e[df5e['Y']<10]['thetaX'],bins=100,histtype=u'step',density=True)
_=plt.hist(df10e[df10e['Y']<10]['thetaX'],bins=100,histtype=u'step',color="cyan",density=True)
_=plt.hist(df20e[df20e['Y']<10]['thetaX'],bins=100,histtype=u'step',color="magenta",density=True)
# _=ax[1,0].hist(df5e[df5e['X']<10]['dY'],bins=100,histtype=u'step',density=True)
# _=ax[1,0].hist(df5g[df5g['X']<10]['dY'],bins=100,histtype=u'step',color="cyan",density=True)

# %%
plt.subplots(2,1,figsize=(4,8))
_=ax[0,0].hist(df5e[df5e['Y']<10]['dX'],bins=100,histtype=u'step',density=True)
_=ax[0,0].hist(df5g[df5g['Y']<10]['dX'],bins=100,histtype=u'step',color="cyan",density=True)
_=ax[1,0].hist(df5e[df5e['X']<10]['dY'],bins=100,histtype=u'step',density=True)
_=ax[1,0].hist(df5g[df5g['X']<10]['dY'],bins=100,histtype=u'step',color="cyan",density=True)
